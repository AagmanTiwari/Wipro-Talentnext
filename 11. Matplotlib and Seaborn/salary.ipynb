# %%
# Perform Exploratory Data Analysis for the dataset  salary_data.csv using Matplotlib and Seaborn libraries.

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv("salary_data.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
# Distribution of YearsExperience
plt.figure(figsize=(8,5))
sns.histplot(df["YearsExperience"], bins=10, kde=True, color="skyblue")
plt.title("Distribution of Years of Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Count")
plt.show()

# %%
# Distribution of Salary
plt.figure(figsize=(8,5))
sns.histplot(df["Salary"], bins=10, kde=True, color="orange")
plt.title("Distribution of Salary")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.show()

# %%
# Boxplots to detect outliers
plt.figure(figsize=(12,5))

# %%
plt.subplot(1,2,1)
sns.boxplot(y=df["YearsExperience"], color="lightblue")
plt.title("Boxplot - Years of Experience")
# Out:
# Text(0.5, 1.0, 'Boxplot - Years of Experience')

# %%
plt.subplot(1,2,2)
sns.boxplot(y=df["Salary"], color="lightgreen")
plt.title("Boxplot - Salary")
# Out:
# Text(0.5, 1.0, 'Boxplot - Salary')

# %%
plt.tight_layout()
plt.show()

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
# Scatterplot of YearsExperience vs Salary
plt.figure(figsize=(8,5))
sns.scatterplot(x="YearsExperience", y="Salary", data=df, color="purple", s=60)
plt.title("Years of Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
# Regression line (trend)
plt.figure(figsize=(8,5))
sns.regplot(x="YearsExperience", y="Salary", data=df, color="green", line_kws={"color":"red"})
plt.title("Regression Line - Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(5,4))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
